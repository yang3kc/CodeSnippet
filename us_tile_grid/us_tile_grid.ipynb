# %%
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
with open('us_tile_grid_coordinates.json', 'r') as f:
    us_tile_grid_coordinates = json.load(f)

# %%
us_tile_grid_coordinates
# Out:
# {'AL': {'row': 6, 'col': 6},
#  'AK': {'row': 0, 'col': 0},
#  'AZ': {'row': 5, 'col': 2},
#  'AR': {'row': 5, 'col': 5},
#  'CA': {'row': 4, 'col': 0},
#  'CO': {'row': 4, 'col': 3},
#  'CT': {'row': 2, 'col': 9},
#  'DC': {'row': 4, 'col': 8},
#  'DE': {'row': 4, 'col': 10},
#  'FL': {'row': 6, 'col': 9},
#  'GA': {'row': 6, 'col': 7},
#  'HI': {'row': 6, 'col': 0},
#  'ID': {'row': 3, 'col': 2},
#  'IL': {'row': 3, 'col': 6},
#  'IN': {'row': 3, 'col': 7},
#  'IA': {'row': 3, 'col': 5},
#  'KS': {'row': 4, 'col': 4},
#  'KY': {'row': 4, 'col': 6},
#  'LA': {'row': 6, 'col': 4},
#  'ME': {'row': 0, 'col': 10},
#  'MD': {'row': 4, 'col': 9},
#  'MA': {'row': 1, 'col': 10},
#  'MI': {'row': 2, 'col': 7},
#  'MN': {'row': 2, 'col': 5},
#  'MS': {'row': 6, 'col': 5},
#  'MO': {'row': 4, 'col': 5},
#  'MT': {'row': 2, 'col': 2},
#  'NE': {'row': 3, 'col': 4},
#  'NV': {'row': 4, 'col': 1},
#  'NH': {'row': 1, 'col': 9},
#  'NJ': {'row': 3, 'col': 10},
#  'NM': {'row': 5, 'col': 3},
#  'NY': {'row': 2, 'col': 8},
#  'NC': {'row': 5, 'col': 8},
#  'ND': {'row': 2, 'col': 3},
#  'OH': {'row': 3, 'col': 8},
#  'OK': {'row': 5, 'col': 4},
#  'OR': {'row': 3, 'col': 1},
#  'PA': {'row': 3, 'col': 9},
#  'RI': {'row': 2, 'col': 10},
#  'SC': {'row': 6, 'col': 8},
#  'SD': {'row': 2, 'col': 4},
#  'TN': {'row': 5, 'col': 6},
#  'TX': {'row': 6, 'col': 3},
#  'UT': {'row': 4, 'col': 2},
#  'VT': {'row': 1, 'col': 8},
#  'VA': {'row': 5, 'col': 7},
#  'WA': {'row': 2, 'col': 1},
#  'WV': {'row': 4, 'col': 7},
#  'WI': {'row': 2, 'col': 6},
#  'WY': {'row': 3, 'col': 3}}

# %%
# Grid dimensions
n_rows = max(coord['row'] for coord in us_tile_grid_coordinates.values()) + 1
n_cols = max(coord['col'] for coord in us_tile_grid_coordinates.values()) + 1

# Create the figure
fig = plt.figure(figsize=(n_cols * 2.5, n_rows * 2.5)) # Adjust figsize as needed

# Dictionary to hold the axes objects, keyed by state
axs = {}

# Iterate through the state locations and create subplots
for state, coord in us_tile_grid_coordinates.items():
    row = coord['row']
    col = coord['col']
    ax = fig.add_subplot(n_rows, n_cols, row * n_cols + col + 1)
    axs[state] = ax

    # Add your plots here
    plt.plot(np.random.randn(10))
    plt.title(state)

plt.tight_layout(rect=[0, 0, 1, 0.96]) # Adjust layout to prevent overlap, leave space for title
# plt.savefig('us_tile_grid.pdf')
plt.show()
